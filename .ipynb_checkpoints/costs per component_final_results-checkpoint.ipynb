# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_component_costs(filepath, component, top_limit):
    # Step 1: Load the CSV file
    df = pd.read_csv(filepath)
    
    # Step 2: Filter the rows excluding the "Total" row
    df_filtered = df[df['component costs'] != 'Total']

    # Step 3: Get the cost columns (excluding the 'component costs' column)
    cost_columns = df_filtered.columns[1:]  # Exclude the 'component costs' column
    
    # Step 4: Convert the data to millions of dollars
    df_filtered[cost_columns] = df_filtered[cost_columns] / 1000000  # Convert to millions

    # Step 5: Transpose the data for plotting
    # The 'component costs' values will become the legend, and the cost columns are the x-axis
    plot_data = df_filtered.set_index('component costs')[cost_columns].T

    # Define specific colors for each component type
    component_colors = {
        'Labor': 'deepskyblue',
        'Raw materials': 'mediumpurple',  # Soft purple
        'Factory amortization': '#FFA07A',  # Soft orange
        'Transportation': 'lightpink',  # Dark purple
        'Other': '#D3D3D3',  # Light grey for 'Other'
        'Tariffs': 'white'
    }

    # Step 6: Plot the stacked bar chart with black borders and custom colors
    ax = plot_data.plot(kind='bar', stacked=True, figsize=(11, 7.7), edgecolor='black', color=[component_colors.get(label, '#D3D3D3') for label in plot_data.columns], zorder=100)

    # Step 7: Customize the plot
    plt.title(component + ' Cost Breakdowns (15-MW Turbine)', fontweight='bold')
    plt.ylabel('Cost (Million $)', fontweight='bold')
    plt.xticks(rotation=0, fontweight='bold')  # Set x-axis labels rotation to 0 and make them bold
    plt.grid(True, axis='y', zorder=10)  # Add horizontal grid lines
    
    # Reverse the order of legend items
    plt.legend(title='Cost Type')
    
    # Step 8: Annotate the bars with values, percentage, and $/kW
    printed_totals = set()  # Set to track which bars have already printed their total cost
    
    for i, rect in enumerate(ax.patches):
        # Get the height of the bar segment
        height = rect.get_height()
        
        # If the value is 0, skip the annotation
        if height == 0:
            continue
        
        # Get the x position (which cost type it belongs to)
        x_pos = rect.get_x() + rect.get_width() / 2

        # Calculate the total height of the bar (sum of all segments for that x position)
        total_height = sum([r.get_height() for r in ax.patches if r.get_x() == rect.get_x()])

        # Calculate the percentage of the total for that specific bar
        percentage = (height / total_height) * 100
        
        # Calculate the $/kW by dividing by 15000 kW
        cost_per_kw = (height * 1000000) / 15000  # Revert to dollars before dividing by 15000
        
        # Explicitly disable LaTeX rendering
        plt.rcParams['text.usetex'] = False

        # Use string formatting with just one dollar sign at the beginning, adding commas for thousands separation
        text = "\$" + "{:,.2f}M | {:.0f}% | ${:,.0f}/kW".format(height, percentage, cost_per_kw)
        
        # Position the text at the middle of the bar segment
        ax.text(x_pos, rect.get_y() + height / 2, text, ha='center', va='center', fontsize=7.5, color='black', zorder=200)

        # Step 9: Add total text on top of each stacked bar (without percentage), with commas for thousands separation
        # Only print the total cost for each bar once
        if rect.get_x() not in printed_totals:  # If this bar hasn't had its total printed yet
            total_cost = total_height  # Total cost in millions
            total_cost_per_kw = (total_height * 1000000) / 15000  # $/kW for the total of the bar

            # Format the total text: "$1.99M | $133/kW", with commas for thousands
            total_text = "\$" + "{:,.2f}M | ${:,.0f}/kW".format(total_cost, total_cost_per_kw)

            # Place the total text at the top of each bar (above the highest segment)
            ax.text(x_pos, total_height * 1.01, total_text, ha='center', va='bottom', fontsize=7.2, color='black', zorder=200)

            # Add this x position to the set so we know this bar has had its total printed
            printed_totals.add(rect.get_x())

    # Step 10: Show the plot
    plt.ylim([0,top_limit])
    plt.tight_layout()
    plt.savefig("figures_outreach/"+ component + filepath.replace(".", "").replace("/", "") + ".svg", format="svg", dpi=300)
    plt.show()

# Example usage:

# %%
plot_component_costs('data_outreach/blades_costs_france_import_NY.csv', '3-Blade Set', 8)
plot_component_costs('data_outreach/blades_costs_denmark_import_VA.csv', '3-Blade Set', 8)
plot_component_costs('data_outreach/blades_costs_denmark_import_GreatLakes.csv', '3-Blade Set', 8)
# Out:
# C:\Users\dmulash\.conda\envs\ORBIT\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\dmulash\.conda\envs\ORBIT\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
plot_component_costs('data_outreach/nacelle_costs_germany_import_NY.csv', 'Nacelle', 27)
plot_component_costs('data_outreach/nacelle_costs_germany_import_NJ.csv', 'Nacelle', 27)
plot_component_costs('data_outreach/nacelle_costs_france_import_NY.csv', 'Nacelle', 27)

# %%
plot_component_costs('data_outreach/tower_costs_denmark_import_NY.csv', 'Tower', 4.8)
plot_component_costs('data_outreach/tower_costs_denmark_import_Michigan.csv', 'Tower', 4.8)
plot_component_costs('data_outreach/tower_costs_denmark_import_MD.csv', 'Tower', 4.8)

# %%
plot_component_costs('data_outreach/tower_costs_Ventower.csv', 'Tower', 6)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_component_costs(filepath, component, top_limit):
    # Step 1: Load the CSV file
    df = pd.read_csv(filepath)
    
    # Step 2: Filter the rows excluding the "Total" row
    df_filtered = df[df['component costs'] != 'Total']

    # Step 3: Get the cost columns (excluding the 'component costs' column)
    cost_columns = df_filtered.columns[1:]  # Exclude the 'component costs' column
    
    # Step 4: Convert the data to millions of dollars
    df_filtered[cost_columns] = df_filtered[cost_columns] / 1000000  # Convert to millions

    # Step 5: Transpose the data for plotting
    # The 'component costs' values will become the legend, and the cost columns are the x-axis
    plot_data = df_filtered.set_index('component costs')[cost_columns].T

    # Define specific colors for each component type
    component_colors = {
        'Labor': 'deepskyblue',
        'Raw materials': 'mediumpurple',  # Soft purple
        'Factory amortization': '#FFA07A',  # Soft orange
        'Transportation': 'lightpink',  # Dark purple
        'Other': '#D3D3D3',  # Light grey for 'Other'
        'Tariffs': 'white'
    }

    # Step 6: Plot the stacked bar chart with black borders and custom colors
    ax = plot_data.plot(kind='bar', stacked=True, figsize=(13, 7.7), edgecolor='black', color=[component_colors.get(label, '#D3D3D3') for label in plot_data.columns], zorder=100)

    # Step 7: Customize the plot
    plt.title(component + ' Cost Breakdowns (15-MW Turbine)', fontweight='bold')
    plt.ylabel('Cost (Million $)', fontweight='bold')
    plt.xticks(rotation=0, fontweight='bold')  # Set x-axis labels rotation to 0 and make them bold
    plt.grid(True, axis='y', zorder=10)  # Add horizontal grid lines
    
    # Reverse the order of legend items
    plt.legend(title='Cost Type')
    
    # Step 8: Annotate the bars with values, percentage, and $/kW
    printed_totals = set()  # Set to track which bars have already printed their total cost
    
    for i, rect in enumerate(ax.patches):
        # Get the height of the bar segment
        height = rect.get_height()
        
        # If the value is 0, skip the annotation
        if height == 0:
            continue
        
        # Get the x position (which cost type it belongs to)
        x_pos = rect.get_x() + rect.get_width() / 2

        # Calculate the total height of the bar (sum of all segments for that x position)
        total_height = sum([r.get_height() for r in ax.patches if r.get_x() == rect.get_x()])

        # Calculate the percentage of the total for that specific bar
        percentage = (height / total_height) * 100
        
        # Calculate the $/kW by dividing by 15000 kW
        cost_per_kw = (height * 1000000) / 15000  # Revert to dollars before dividing by 15000
        
        # Explicitly disable LaTeX rendering
        plt.rcParams['text.usetex'] = False

        # Use string formatting with just one dollar sign at the beginning, adding commas for thousands separation
        text = "\$" + "{:,.2f}M | {:.0f}% | ${:,.0f}/kW".format(height, percentage, cost_per_kw)
        
        # Position the text at the middle of the bar segment
        ax.text(x_pos, rect.get_y() + height / 2, text, ha='center', va='center', fontsize=7.5, color='black', zorder=200)

        # Step 9: Add total text on top of each stacked bar (without percentage), with commas for thousands separation
        # Only print the total cost for each bar once
        if rect.get_x() not in printed_totals:  # If this bar hasn't had its total printed yet
            total_cost = total_height  # Total cost in millions
            total_cost_per_kw = (total_height * 1000000) / 15000  # $/kW for the total of the bar

            # Format the total text: "$1.99M | $133/kW", with commas for thousands
            total_text = "\$" + "{:,.2f}M | ${:,.0f}/kW".format(total_cost, total_cost_per_kw)

            # Place the total text at the top of each bar (above the highest segment)
            ax.text(x_pos, total_height * 1.01, total_text, ha='center', va='bottom', fontsize=7.2, color='black', zorder=200)

            # Add this x position to the set so we know this bar has had its total printed
            printed_totals.add(rect.get_x())

    # Step 10: Show the plot
    plt.ylim([0,top_limit])
    plt.tight_layout()
    plt.savefig("figures_outreach/"+ component + filepath.replace(".", "").replace("/", "") + ".svg", format="svg", dpi=300)
    plt.show()

# Example usage:

# %%
plot_component_costs('data_outreach/tower_costs_US_Forged_Rings.csv', 'Tower', 6)

# %%
plot_component_costs('data_outreach/monopile_costs_germany_import_NJ.csv', 'Monopile', 16.5)
plot_component_costs('data_outreach/monopile_costs_germany_import_MD.csv', 'Monopile', 16.5)

# %%
plot_component_costs('data_outreach/monopile_costs_EEW.csv', 'Monopile', 16.5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_component_costs(filepath, component, top_limit):
    # Step 1: Load the CSV file
    df = pd.read_csv(filepath)
    
    # Step 2: Filter the rows excluding the "Total" row
    df_filtered = df[df['component costs'] != 'Total']

    # Step 3: Get the cost columns (excluding the 'component costs' column)
    cost_columns = df_filtered.columns[1:]  # Exclude the 'component costs' column
    
    # Step 4: Convert the data to millions of dollars
    df_filtered[cost_columns] = df_filtered[cost_columns] / 1000000  # Convert to millions

    # Step 5: Transpose the data for plotting
    # The 'component costs' values will become the legend, and the cost columns are the x-axis
    plot_data = df_filtered.set_index('component costs')[cost_columns].T

    # Define specific colors for each component type
    component_colors = {
        'Labor': 'deepskyblue',
        'Raw materials': 'mediumpurple',  # Soft purple
        'Factory amortization': '#FFA07A',  # Soft orange
        'Transportation': 'lightpink',  # Dark purple
        'Other': '#D3D3D3'  # Light grey for 'Other'
    }

    # Step 6: Plot the stacked bar chart with black borders and custom colors
    ax = plot_data.plot(kind='bar', stacked=True, figsize=(11, 7.7), edgecolor='black', color=[component_colors.get(label, '#D3D3D3') for label in plot_data.columns], zorder=100)

    # Step 7: Customize the plot
    plt.title(component + ' Cost Breakdowns (per km)', fontweight='bold')
    plt.ylabel('Cost (Million $)', fontweight='bold')
    plt.xticks(rotation=0, fontweight='bold')  # Set x-axis labels rotation to 0 and make them bold
    plt.grid(True, axis='y', zorder=10)  # Add horizontal grid lines
    
    # Reverse the order of legend items
    plt.legend(title='Cost Type')
    
    # Step 8: Annotate the bars with values, percentage, and $/kW
    printed_totals = set()  # Set to track which bars have already printed their total cost
    
    for i, rect in enumerate(ax.patches):
        # Get the height of the bar segment
        height = rect.get_height()
        
        # If the value is 0, skip the annotation
        if height == 0:
            continue
        
        # Get the x position (which cost type it belongs to)
        x_pos = rect.get_x() + rect.get_width() / 2

        # Calculate the total height of the bar (sum of all segments for that x position)
        total_height = sum([r.get_height() for r in ax.patches if r.get_x() == rect.get_x()])

        # Calculate the percentage of the total for that specific bar
        percentage = (height / total_height) * 100
        
        # Calculate the $/kW by dividing by 15000 kW
        cost_per_km = height  # Revert to dollars before dividing by 15000
        
        # Explicitly disable LaTeX rendering
        plt.rcParams['text.usetex'] = False

        # Use string formatting with just one dollar sign at the beginning, adding commas for thousands separation
        text = "{:.0f}% | ${:,.2f}M/km".format(percentage, cost_per_km)
        
        # Position the text at the middle of the bar segment
        ax.text(x_pos, rect.get_y() + height / 2, text, ha='center', va='center', fontsize=7.5, color='black', zorder=200)

        # Step 9: Add total text on top of each stacked bar (without percentage), with commas for thousands separation
        # Only print the total cost for each bar once
        if rect.get_x() not in printed_totals:  # If this bar hasn't had its total printed yet
            total_cost = total_height  # Total cost in millions
            total_cost_per_km = total_height  # $/kW for the total of the bar

            # Format the total text: "$1.99M | $133/kW", with commas for thousands
            total_text = "\${:,.2f}M/km".format(total_cost_per_km)

            # Place the total text at the top of each bar (above the highest segment)
            ax.text(x_pos, total_height * 1.01, total_text, ha='center', va='bottom', fontsize=7.5, color='black', zorder=200)

            # Add this x position to the set so we know this bar has had its total printed
            printed_totals.add(rect.get_x())

    # Step 10: Show the plot
    plt.ylim([0,top_limit])
    plt.tight_layout()
    plt.savefig("figures_outreach/"+ component + filepath.replace(".", "").replace("/", "") + ".svg", format="svg", dpi=300)
    plt.show()

# %%
plot_component_costs('data_outreach/array_cable_costs_unitedkingdom_import_VA.csv', '66 kV 630 mm Array Cable', 1)

# %%
plot_component_costs('data_outreach/export_cable_costs_finland_import_SC.csv', '220 kV 1,000 mm Export Cable', 1.9)
plot_component_costs('data_outreach/export_cable_costs_finland_import_MA.csv', '220 kV 1,000 mm Export Cable', 1.9)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_component_costs(filepath, component, top_limit):
    # Step 1: Load the CSV file
    df = pd.read_csv(filepath)
    
    # Step 2: Filter the rows excluding the "Total" row
    df_filtered = df[df['component costs'] != 'Total']

    # Step 3: Get the cost columns (excluding the 'component costs' column)
    cost_columns = df_filtered.columns[1:]  # Exclude the 'component costs' column
    
    # Step 4: Convert the data to millions of dollars
    df_filtered[cost_columns] = df_filtered[cost_columns] / 1000000  # Convert to millions

    # Step 5: Transpose the data for plotting
    # The 'component costs' values will become the legend, and the cost columns are the x-axis
    plot_data = df_filtered.set_index('component costs')[cost_columns].T

    # Define specific colors for each component type
    component_colors = {
        'Labor': 'deepskyblue',
        'Raw materials': 'mediumpurple',  # Soft purple
        'Factory amortization': '#FFA07A',  # Soft orange
        'Transportation': 'lightpink',  # Dark purple
        'Other': '#D3D3D3',  # Light grey for 'Other'
        'Tariffs': 'white'
    }

    # Step 6: Plot the stacked bar chart with black borders and custom colors
    ax = plot_data.plot(kind='bar', stacked=True, figsize=(11, 7.7), edgecolor='black', color=[component_colors.get(label, '#D3D3D3') for label in plot_data.columns], zorder=100)

    # Step 7: Customize the plot
    plt.title(component + ' Cost Breakdowns (15-MW Turbine, 40 meters of Water Depth)', fontweight='bold')
    plt.ylabel('Cost (Million $)', fontweight='bold')
    plt.xticks(rotation=0, fontweight='bold')  # Set x-axis labels rotation to 0 and make them bold
    plt.grid(True, axis='y', zorder=10)  # Add horizontal grid lines
    
    # Reverse the order of legend items
    plt.legend(title='Cost Type')
    
    # Step 8: Annotate the bars with values, percentage, and $/kW
    printed_totals = set()  # Set to track which bars have already printed their total cost
    
    for i, rect in enumerate(ax.patches):
        # Get the height of the bar segment
        height = rect.get_height()
        
        # If the value is 0, skip the annotation
        if height == 0:
            continue
        
        # Get the x position (which cost type it belongs to)
        x_pos = rect.get_x() + rect.get_width() / 2

        # Calculate the total height of the bar (sum of all segments for that x position)
        total_height = sum([r.get_height() for r in ax.patches if r.get_x() == rect.get_x()])

        # Calculate the percentage of the total for that specific bar
        percentage = (height / total_height) * 100
        
        # Calculate the $/kW by dividing by 15000 kW
        cost_per_kw = (height * 1000000) / 15000  # Revert to dollars before dividing by 15000
        
        # Explicitly disable LaTeX rendering
        plt.rcParams['text.usetex'] = False

        # Use string formatting with just one dollar sign at the beginning, adding commas for thousands separation
        text = "\$" + "{:,.2f}M | {:.0f}% | ${:,.0f}/kW".format(height, percentage, cost_per_kw)
        
        # Position the text at the middle of the bar segment
        ax.text(x_pos, rect.get_y() + height / 2, text, ha='center', va='center', fontsize=7.5, color='black', zorder=200)

        # Step 9: Add total text on top of each stacked bar (without percentage), with commas for thousands separation
        # Only print the total cost for each bar once
        if rect.get_x() not in printed_totals:  # If this bar hasn't had its total printed yet
            total_cost = total_height  # Total cost in millions
            total_cost_per_kw = (total_height * 1000000) / 15000  # $/kW for the total of the bar

            # Format the total text: "$1.99M | $133/kW", with commas for thousands
            total_text = "\$" + "{:,.2f}M | ${:,.0f}/kW".format(total_cost, total_cost_per_kw)

            # Place the total text at the top of each bar (above the highest segment)
            ax.text(x_pos, total_height * 1.01, total_text, ha='center', va='bottom', fontsize=7.2, color='black', zorder=200)

            # Add this x position to the set so we know this bar has had its total printed
            printed_totals.add(rect.get_x())

    # Step 10: Show the plot
    plt.ylim([0,top_limit])
    plt.tight_layout()
    plt.savefig("figures_outreach/"+ component + filepath.replace(".", "").replace("/", "") + ".svg", format="svg", dpi=300)
    plt.show()

# Example usage:

# %%
plot_component_costs('data_outreach/monopile_costs_EEW.csv', 'Monopile', 16.5)
